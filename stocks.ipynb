# %%
import yfinance as yf
import pandas as pd

def stockfunction(symbol):
    x = symbol.financials
    df = pd.DataFrame(data=x)
    print(df)
    df = df.reset_index()
    df.columns = ['Stats', 4, 3, 2, 1]
    df = df.drop('Stats', axis=1)
    df.columns = [4, 3, 2, 1]
    
    
    revenue = []
    for y in range(4):
        y = y+1
        revitem = df.loc[15,y]
        revenue.append(revitem)
        
        
    grossprofit = []
    for y in range(4):
        y = y +1
        gprofititem = df.loc[6,y]
        grossprofit.append(gprofititem)
        
    netincome = []
    for y in range(4):
        y = y + 1
        netitem = df.loc[4,y]
        netincome.append(netitem)
    print(netincome)
        
    netprofitmargin = []
    for y in range(4):
        netprofitmitem = (netincome[y]/revenue[y]) * 100
        netprofitmargin.append(netprofitmitem)
    
        
    del df
    
    cashflowinfo = symbol.cashflow
    df = pd.DataFrame(data=cashflowinfo)
    df = df.reset_index()
    df.columns = ['Names', 4, 3, 2, 1]
    df = df.drop('Names', axis=1)
    df.columns = [4, 3, 2, 1]
    
    changetoliab = []
    for y in range(4):
        y = y + 1
        changetoliabitem = df.loc[1, y]
        changetoliab.append(changetoliabitem)
    
    changeincash = []
    for y in range(4):
        y = y + 1
        changeincashitem = df.loc[8, y]
        changeincash.append(changeincashitem)
        
    totalcashfromoperations = []
    for y in range(4):
        y = y + 1
        totalcashfromoperationsitem = df.loc[10, y]
        totalcashfromoperations.append(totalcashfromoperationsitem)
        
    del df
    
    balancesheet = symbol.balance_sheet
    df = pd.DataFrame(data=balancesheet)
    print(df)
    df = df.reset_index()
    df.columns = ['Labels', 4, 3, 2, 1]
    df = df.drop('Labels', axis=1)
    df.columns = [4, 3, 2, 1]
    
    cash = []
    for y in range(4):
        y = y + 1
        cashitem = df.loc[10, y]
        cash.append(cashitem)
    
    totalassets = []
    for y in range(4):
        y = y + 1
        totalassetsitem = df.loc[3, y]
        totalassets.append(totalassetsitem)
    
    totalliabilities = []
    for y in range(4):
        y = y + 1
        totalliabitem = df.loc[0, y]
        totalliabilities.append(totalliabitem)
    
    
        
    
    
    print(df)
    
    
    
    
    
apple = yf.Ticker("SND")
stockfunction(apple)

def collector(num, array):
    return array

pricedata = yf.download('ACAB', '2018-01-01', '2022-01-01')
df = pd.DataFrame(data=pricedata)
print(df)

arr= [3,4,5,6]
print(arr[-1])
# Out:
#                                          2021-12-31   2020-12-31   2019-12-31  \
# Research Development                           None         None         None
# Effect Of Accounting Charges                   None         None         None
# Income Before Tax                       -59691000.0   24974000.0   39432000.0
# Minority Interest                              None         None         None
# Net Income                              -50674000.0   37954000.0   31623000.0
# Selling General Administrative           26007000.0   24629000.0   22888000.0
# Gross Profit                            -15906000.0   18119000.0   81052000.0
# Ebit                                    -43893000.0   -8421000.0   55753000.0
# Operating Income                        -43893000.0   -8421000.0   55753000.0
# Other Operating Expenses                       None         None         None
# Interest Expense                         -2014000.0   -2129000.0   -3626000.0
# ...
